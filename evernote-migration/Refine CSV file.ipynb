# %%
import bs4, urllib, re, pandas as pd, numpy as np

# %%
collection = pd.read_csv('wsb_catalog_v2.csv')

# %%
collection = collection.sort_values(by=['Year', 'Schottlaender v4.0'])

# %%
collection
# Out:
#                                                  Title  Year  \
# 0                                               Junkie  1953
# 1                                               Junkie  1953
# 2                                               Junkie  1957
# 3                                 Chicago Review 12(3)  1958
# 4                                      The Naked Lunch  1959
# 6                                          Big Table 1  1959
# 5                                          Big Table 2  1959
# 7                                     The Exterminator  1960
# 8                                     The Exterminator  1960
# 9                                        Minutes To Go  1960
# 10                                         Big Table 4  1960
# 11                                    The Soft Machine  1961
# 12                                 The Floating Bear 5  1961
# 13                                      The Outsider 1  1961
# ...

# %%
collection.to_csv('wsb_catalog_v3.csv', index=False)
